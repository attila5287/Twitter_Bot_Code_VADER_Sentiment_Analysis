# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import datetime
import time
import warnings
warnings.filterwarnings("ignore")
import api_keys
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
consumer_key = api_keys.consumer_key
consumer_secret = api_keys.consumer_secret
access_token = api_keys.access_token
access_token_secret = api_keys.access_token_secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# ====================== tellmeabout ===============================
# parameters: (data)  *type objects along the way to see their type and size
def tellmeabout(data):
    print(type(data))
    print('length:' + str(len(data)))

# %% [markdown]
#  - Twitter data structure/JSON format shown below (ref: Twitter Developer Doc.)
#  - required to examine before an api call to retrieve data from JSON>dict

# %%
# api_json

# {
#   "created_at": "Thu Apr 06 15:24:15 +0000 2017",
#   "id_str": "850006245121695744",
#   "text": "1\/ Today we\u2019re sharing our vision for the future of the Twitter API platform!\nhttps:\/\/t.co\/XweGngmxlP",
#   "user": {
#     "id": 2244994945,
#     "name": "Twitter Dev",
#     "screen_name": "TwitterDev",
#     "location": "Internet",
#     "url": "https:\/\/dev.twitter.com\/",
#     "description": "Your official source for Twitter Platform news, updates & events. Need technical help? Visit https:\/\/twittercommunity.com\/ \u2328\ufe0f #TapIntoTwitter"
#   },
#   "place": {   
#   },
#   "entities": {
#     "hashtags": [      
#     ],
#     "urls": [
#       {
#         "url": "https:\/\/t.co\/XweGngmxlP",
#         "unwound": {
#           "url": "https:\/\/cards.twitter.com\/cards\/18ce53wgo4h\/3xo1c",
#           "title": "Building the Future of the Twitter API Platform"
#         }
#       }
#     ],
#     "user_mentions": []}}

# %%
AccountsList = ["FoxNews", "CNN", "BBCWorld", "CBSNews", "nytimes"]

# %%
# ====================== MoodPyTwitter ===============================
# ** define a function that will retrieve data from twitter iterating through list of names 
# parameters: (AccountList= input_list, pagecount= scalar value)
# -----------AccountsList =['Twitter', 'Twitter_Developer', 'TwitterHelp] should be series/list for iteration
# -----------pagecount = 5, integer. ** given as 5 on the assignment. 
# ---------------------** run 1-2 for tests 0 to review blank data structure
# moodpy_df = pd.DataFrame({'Date' : [],'SourceName': [],'Texts': [],'VaderComp': [],'VaderNeut': [],'VaderNeg':[]})

def MoodPyTwitter(AccountsList,pagecount):
# reset the output before every use 
    global moodpy_df
    global Copy_Rename_Output_df
    moodpy_df = pd.DataFrame({'Date' : [],'SourceName': [],'Texts': [],'VaderComp': [],'VaderNeut': [],'VaderNeg':[]})
    today = datetime.date.today()

    print(">> #MoodPyTwitter ",today)
# (0)create lists to store api_json data
# reference: above twitter documentation code for JSON keys and data structure of a tweet
    Sources, Texts, DateList, Compounds, Positives, Neutrals, Negatives = [],[],[],[],[],[],[]
# Iter1: iterate through pages input/also a parameter of above defined function  
    for page in range(pagecount):
        print("page %s / %s " % ((page+1),pagecount))
#         print("City weather records: requesting %s of %s | %s" % (rand_city.index(city)+1, city_count+1, city))
        acct_count = len(AccountsList)
        
# Iter2: iterate through all accounts stored in the Accounts (list)
        for account in AccountsList:
            acct_current = AccountsList.index(account)+1
            print("  - User   ",acct_current, " of ",acct_count," ", account, " twitter data retrieving...")

# Request data from Twitter via api call to twitter 
# returns a list (Tweets) of dictionaries
            Tweets= api.user_timeline(account, page=page)     

# Iter3: iterate through each tweet-type: dictionary 
# tweet iterable is a dictionary stored in Tweets list thus need to iterate elements individually
            for tweet in Tweets:
# Iter3(p1)- - - -obtain name-tweet_text-date (source name for re-tweets)
                DateList.append(tweet['created_at'])
                Sources.append(tweet['user']['name'])
                Texts.append(tweet['text'])
# Iter3(p2) - - - Vader analysis on text of each tweet:
                Compounds.append(analyzer.polarity_scores(tweet["text"])["compound"])
                Positives.append(analyzer.polarity_scores(tweet["text"])["pos"])
                Neutrals.append(analyzer.polarity_scores(tweet["text"])["neu"])
                Negatives.append(analyzer.polarity_scores(tweet["text"])["neg"])

    moodpy_df = pd.DataFrame({'Date' : DateList,'SourceName': Sources,'Texts': Texts,'VaderComp': Compounds,'VaderNeut':Neutrals,'VaderNeg':Negatives})
    Copy_Rename_Output_df = moodpy_df.copy()       
    # ====================== MoodPyTwitter: OUTPUT ===============================
    print("\n>> Output ",today)
    print('*  Total of  500  tweets stored in a global variable')
    print('*  Please copy/paste below to rename output dataframe as below') 
    print(" _df = Copy_Rename_Output_df.copy() ")

    return moodpy_df.tail(2)

# %%
acct_list = ["FoxNews", "CNN", "BBCWorld", "CBSNews", "nytimes"]
MoodPyTwitter(acct_list,5)
# Out:
# >> #MoodPyTwitter  2018-10-16
# page 1 / 5
#   - User    1  of  5   FoxNews  twitter data retrieving...
#   - User    2  of  5   CNN  twitter data retrieving...
#   - User    3  of  5   BBCWorld  twitter data retrieving...
#   - User    4  of  5   CBSNews  twitter data retrieving...
#   - User    5  of  5   nytimes  twitter data retrieving...
# page 2 / 5
#   - User    1  of  5   FoxNews  twitter data retrieving...
#   - User    2  of  5   CNN  twitter data retrieving...
#   - User    3  of  5   BBCWorld  twitter data retrieving...
#   - User    4  of  5   CBSNews  twitter data retrieving...
#   - User    5  of  5   nytimes  twitter data retrieving...
# page 3 / 5
#   - User    1  of  5   FoxNews  twitter data retrieving...
#   - User    2  of  5   CNN  twitter data retrieving...
#   - User    3  of  5   BBCWorld  twitter data retrieving...
#   - User    4  of  5   CBSNews  twitter data retrieving...
#   - User    5  of  5   nytimes  twitter data retrieving...
# page 4 / 5
#   - User    1  of  5   FoxNews  twitter data retrieving...
#   - User    2  of  5   CNN  twitter data retrieving...
#   - User    3  of  5   BBCWorld  twitter data retrieving...
#   - User    4  of  5   CBSNews  twitter data retrieving...
#   - User    5  of  5   nytimes  twitter data retrieving...
# page 5 / 5
#   - User    1  of  5   FoxNews  twitter data retrieving...
#   - User    2  of  5   CNN  twitter data retrieving...
#   - User    3  of  5   BBCWorld  twitter data retrieving...
#   - User    4  of  5   CBSNews  twitter data retrieving...
#   - User    5  of  5   nytimes  twitter data retrieving...
#
# >> Output  2018-10-16
# *  Total of  500  tweets stored in a global variable
# *  Please copy/paste below to rename output dataframe as below
#  _df = Copy_Rename_Output_df.copy()
#                                Date          SourceName  \
# 498  Mon Oct 15 15:04:06 +0000 2018  The New York Times
# 499  Mon Oct 15 14:54:03 +0000 2018  The New York Times
#
#                                                  Texts  VaderComp  VaderNeut  \
# 498  RT @nytimesworld: Medal-winning South Korean a...        0.0        1.0
# 499  What we know — and what we don't — about Jamal...        0.0        1.0
#
#      VaderNeg
# 498       0.0
# 499       0.0

# %%
#  per instructions above (output of MoodPyTwitter function)
plot_df = Copy_Rename_Output_df.copy() 
# plot_df.columns ['Date', 'SourceName', 'Texts', 'VaderComp', 'VaderNeut', 'VaderNeg']
plot_df.count()
# Out:
# Date          500
# SourceName    500
# Texts         500
# VaderComp     500
# VaderNeut     500
# VaderNeg      500
# dtype: int64

# %%
plot_df.head()
# Out:
#                              Date SourceName  \
# 0  Tue Oct 16 06:00:00 +0000 2018   Fox News
# 1  Tue Oct 16 05:45:00 +0000 2018   Fox News
# 2  Tue Oct 16 05:30:00 +0000 2018   Fox News
# 3  Tue Oct 16 05:15:00 +0000 2018   Fox News
# 4  Tue Oct 16 05:00:00 +0000 2018   Fox News
#
#                                                Texts  VaderComp  VaderNeut  \
# 0  .@POTUS on Hurricane Michael damage: "We've ca...    -0.0258      0.717
# 1  A judge dismissed a defamation lawsuit on Mond...    -0.2263      0.894
# 2  Prince Harry and Meghan, Duchess of Sussex, me...     0.0000      1.000
# 3  Florida middle school allegedly calls out stud...    -0.2960      0.872
# 4  San Francisco is set to vote on taxing large c...     0.0000      1.000
#
#    VaderNeg
# 0     0.143
# 1     0.106
# 2     0.000
# 3     0.128
# 4     0.000

# %%
# before inserting x_axis index values such as -100, -99, -98....0: first need to sort _df by date
plot_df['Date_dt'] = pd.to_datetime(plot_df['Date'])
# above was required in order to create another series without overwriting original data
# helpful for using datetime module functions-if required- and lastly shows data presentable
plot_df = plot_df.sort_values("Date_dt", ascending=False)

# %%
# creates a level_0 index where the latest tweet will be zero and the rest will be integer 
# series of single increments 
plot_df = plot_df.reset_index()

# %%
# drop index column after above method reset_index()
plot_df = plot_df.drop(columns='index')

# %%
# ====================== TweetPlotVComp ===============================
# ** define a function that will plot summarizing Vader analysis results
#     by scattering Compound index of tweets with respect to age
# parameters: (SortedByDateLatestFirst_df: should be a dataframe sorted with dates/latest on row 0
#              acct_plotlist: a list consisting of twitter accounts pre-Vader_analyzed>to be plotted    

def TweetSplashVComp(SortedByDateLatestFirst_df,acct_plotlist):
    #  ['BBC News (World)', 'CNN', 'CBS News', 'The New York Times', 'Fox News']

    plt.figure(figsize=(18,10))
    plt.rcParams["font.size"] = 12
    today = datetime.date.today()
    print(">> #TweetPlotVComp ",today)
    print( 'VADER Compound Index plotted for: ' )    
    
    for source in acct_plotlist:
        #     create a series for each source 
        sourcecomp_series = plot_df[plot_df['SourceName'] == source]['VaderComp']
        #     sort tweets' vader comp with respect to number of how many tweets-distance from latest post
        x_axis = np.arange(-len(sourcecomp_series),0,1)

        #parameters: please see above for details/second line: plot cosmetics         
        plt.scatter(x_axis,sourcecomp_series,
                    edgecolor="black", linewidths=1.5,s=90,alpha=0.8, label= source)
        print( '\t\t ',str(len(sourcecomp_series)),' tweets by', source)
          
             
    plt.xlabel('Last '+  str(len(sourcecomp_series)) + ' tweets\n Latest tweet: 0 to oldest post in requested data set ' )
    plt.ylabel('VADER Analysis Results: Compound Index \n Varies from -1 to +1: least liked and most liked')
    plt.title('TweetPlotVComp shows VADER Analysis results :')   
    plt.legend(loc='best')
    plt.grid()
    file_nameSCT = "Fig-ScatterPlot.png"
    plt.savefig(file_nameSCT)
    plt.show()
    print("\n>> Output ",today)
    print('*Y axis> Vader Analysis: Compound index plotted | -1 worst 0 neutral 1 best')
    print('*X axis> Age of Tweets | 0: latest tweet LeftMin: oldest ')

# %%
acct_plotlist=  ['BBC News (World)', 'CNN', 'CBS News', 'The New York Times', 'Fox News']
TweetSplashVComp(plot_df,acct_plotlist)
# Out:
# >> #TweetPlotVComp  2018-10-16
# VADER Compound Index plotted for:
# 		  100  tweets by BBC News (World)
# 		  100  tweets by CNN
# 		  100  tweets by CBS News
# 		  100  tweets by The New York Times
# 		  100  tweets by Fox News
# >> Output  2018-10-16
# *Y axis> Vader Analysis: Compound index plotted | -1 worst 0 neutral 1 best
# *X axis> Age of Tweets | 0: latest tweet LeftMin: oldest

# %%
# ====================== TweetPlotVComp ===============================
# ** define a function that will plot summarizing Vader analysis results
#     by scattering Compound index of tweets with respect to age
# parameters: (SortedByDateLatestFirst_df: should be a dataframe sorted with dates/latest on row 0
#              acct_plotlist: a list consisting of twitter accounts pre-Vader_analyzed>to be plotted    

def TweetSplashLineVComp(SortedByDateLatestFirst_df,acct_plotlist):
    today = datetime.date.today()
    print(">> #TweetPlotVComp ",today)
    print( 'VADER Compound Index plotted for: ' )
    global TweetSplashLineVComp_filenamelist
    TweetSplashLineVComp_filenamelist=[]
    color_list = ['b',  'c', 'm', 'y']
    
    for source, color in zip(acct_plotlist,color_list):
        plt.figure(figsize=(18,10))
        plt.rcParams["font.size"] = 12
#         plt.xlabel('Last '+  str(len(sourcecomp_series)) + ' tweets\n Latest tweet: 0 to oldest post in requested data set ' )
        plt.title('TweetPlotVComp shows VADER Analysis results :')   
        #     create a series for each source 
        sourcecomp_series = plot_df[plot_df['SourceName'] == source]['VaderComp']
        #     sort tweets' vader comp with respect to number of how many tweets-distance from latest post
        x_axis = np.arange(-len(sourcecomp_series),0,1)

        #parameters: please see above for details/second line: plot cosmetics         
        plt.plot(x_axis,sourcecomp_series, color=color,linestyle="--",linewidth =0.9, alpha=0.9, marker ='o',  label= source)
        plt.ylabel('VADER Analysis Results: \n Varies from -1 to +1: least liked and most liked')
        plt.xlabel(source)
        print( '\t\t ',str(len(sourcecomp_series)),' tweets by', source, " below")
        plt.grid()
        filename_dashlineball = str(source)+"_"+str(today)+ "_LinePlot"
        print(filename_dashlineball)
        plt.savefig(filename_dashlineball)
        plt.show()
        TweetSplashLineVComp_filenamelist.append(filename_dashlineball)
    
            
    print("\n>> Output ",today)
    print('*Y axis> Vader Analysis: Compound index plotted | -1 worst 0 neutral 1 best')
    print('*X axis> Age of Tweets | 0: latest tweet LeftMin: oldest ')

# %%
acct_plotlist2=  ['BBC News (World)', 'CNN', 'CBS News', 'The New York Times', 'Fox News']
TweetSplashLineVComp(plot_df,acct_plotlist2)
# Out:
# >> #TweetPlotVComp  2018-10-16
# VADER Compound Index plotted for:
# 		  100  tweets by BBC News (World)  below
# BBC News (World)_2018-10-16_LinePlot
# 		  100  tweets by CNN  below
# CNN_2018-10-16_LinePlot
# 		  100  tweets by CBS News  below
# CBS News_2018-10-16_LinePlot
# 		  100  tweets by The New York Times  below
# The New York Times_2018-10-16_LinePlot
# >> Output  2018-10-16
# *Y axis> Vader Analysis: Compound index plotted | -1 worst 0 neutral 1 best
# *X axis> Age of Tweets | 0: latest tweet LeftMin: oldest

# %%
for file in TweetSplashLineVComp_filenamelist:
    api.update_with_media(file+'.png','VADER Analysis Results: \n Varies from -1 to +1: least liked and most liked')
#     TweetSplashLineVComp_filenamelist

# %% [markdown]
# ## Overall Sentiment Bar Graph

# %%
# polarity will be equal to mean average of each label/columns
# please refer to MoodPyTwitter function output
bargraph_df = Copy_Rename_Output_df.copy()

# %%
#  tellmeabout(bargraph_df) confirmed now groupby SourceName>mean
bargraph_df.groupby('SourceName').mean()
# Out:
#                     VaderComp  VaderNeut  VaderNeg
# SourceName
# BBC News (World)    -0.143239    0.81344   0.13248
# CBS News            -0.047172    0.82144   0.10081
# CNN                  0.070824    0.87884   0.05055
# Fox News             0.039519    0.85474   0.06617
# The New York Times  -0.041452    0.85776   0.07796

# %%
acct_barlist = ['BBC News (World)', 'CNN', 'CBS News', 'The New York Times', 'Fox News']

# %%
def TweetBarHappyHour(MoodPyTwitterOutput_df,acct_barlist):
    plt.figure(figsize=(12,6))
    plt.rcParams["font.size"] = 14
    plt.grid()
    plt.title("Overall Average of Selected Twitter Accounts")
    plt.xlabel('Twitter Account')
    plt.ylabel('VaderComp Overall Average')
#     parameter: create an axis with all around average
    bar_values = MoodPyTwitterOutput_df.groupby('SourceName').mean()['VaderComp']
    bar_index = bar_values.index
    plt.bar(bar_index,
            bar_values,
            color = 'g',  alpha = 0.45, align='center',  edgecolor = 'black', linewidth=3,label='Overall Sentimental Average')
    plt.legend(loc='best')
    file_nameBAR = "Fig-BarChart.png"
    plt.savefig(file_nameBAR)
    plt.show()

# %%
TweetBarHappyHour(bargraph_df,acct_barlist)

# %%
def ColorLabelTweetBarHappyHour(MoodPyTwitterOutput_df,acct_barlist):
    plt.figure(figsize=(12,6))
    plt.rcParams["font.size"] = 14
    plt.grid()
    plt.title("Overall Average of Selected Twitter Accounts")
    plt.xlabel('Twitter Account')
    plt.ylabel('VaderComp Overall Average')

#parameter: create an axis with all around average
    bar_values = MoodPyTwitterOutput_df.groupby('SourceName').mean()['VaderComp']
    bar_index = bar_values.index
# iterate through each item of above paratemeters/note both series    
    global file_nameBARcolorList
    file_nameBARcolorList =[]
    for i in range(len(bar_index)):
        source = bar_index[i]
        value = bar_values[i]
        plt.bar(source, value, alpha = 0.75, align='center', edgecolor = 'black', linewidth=2, label= source)
        file_nameBARcolor = source+"-BarChart_color.png"
        plt.savefig(file_nameBARcolor)
        file_nameBARcolorList.append(file_nameBARcolor)
    plt.legend(loc='best')
    plt.show()

# %%
ColorLabelTweetBarHappyHour(bargraph_df,acct_barlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e31608ad7260> in <module>()
# ----> 1 ColorLabelTweetBarHappyHour(bargraph_df,acct_barlist)
#
# NameError: name 'bargraph_df' is not defined

# %%
for file in TweetSplashLineVComp_filenamelist:
    api.update_with_media(file+'.png','VADER Analysis Results: \n from -1 to +1: least liked and most liked'+hashtags)

# %%
for file in TweetSplashLineVComp_filenamelist:
    api.update_with_media(file+'.png','VADER Analysis Results: \n from -1 to +1: least liked and most liked'+hashtags)

# %%
for file in file_nameBARcolorList:

    api.update_with_media(file,'BBC News , CNN, CBS News, The New York Times, Fox News VADER Sentiment Analysis Results '+ hashtags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-dfd4a5d04951> in <module>()
# ----> 1 for file in file_nameBARcolorList:
#       2
#       3     api.update_with_media(file,'BBC News , CNN, CBS News, The New York Times, Fox News VADER Sentiment Analysis Results '+ hashtags)
#
# NameError: name 'file_nameBARcolorList' is not defined

# %%
api.update_with_media(file_nameSCT,'BBC News , CNN, CBS News, The New York Times, Fox News: VADER analysis'+hashtags)
# Out:
# {'created_at': 'Sun Oct 14 13:39:38 +0000 2018',
#  'id': 1051467570447040512,
#  'id_str': '1051467570447040512',
#  'text': 'BBC News , CNN, CBS News, The New York Times, Fox News: VADER analysis#abdsc #DataScience #BigData #DataScientists… https://t.co/mnvZCVq38A',
#  'truncated': True,
#  'entities': {'hashtags': [{'text': 'DataScience', 'indices': [77, 89]},
#    {'text': 'BigData', 'indices': [90, 98]},
#    {'text': 'DataScientists', 'indices': [99, 114]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/mnvZCVq38A',
#     'expanded_url': 'https://twitter.com/i/web/status/1051467570447040512',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [116, 139]}]},
#  'source': '<a href="https://github.com/attila5287" rel="nofollow">Twitter_BigData_DU_Bootcamp_app</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 874542160011382784,
#   'id_str': '874542160011382784',
#   'name': 'Attila Türköz',
#   'screen_name': 'attila52__',
#   'location': 'Denver, CO',
#   'description': "#bogazici #sultans #BJK #denver #colorado #turkey #izmir #istanbul #ataturk #engineer #finance Bogazici ME’11-CTU,https://t.co/21K8KiJUm4'13-Denver Uni’18 #python #bigdata",
#   'url': 'https://t.co/BBmL0lVDO4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BBmL0lVDO4',
#       'expanded_url': 'http://www.bogazicisultans.com',
#       'display_url': 'bogazicisultans.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/21K8KiJUm4',
#       'expanded_url': 'http://MBA.Finance',
#       'display_url': 'MBA.Finance',
#       'indices': [114, 137]}]}},
#   'protected': False,
#   'followers_count': 54,
#   'friends_count': 613,
#   'listed_count': 1,
#   'created_at': 'Tue Jun 13 08:21:13 +0000 2017',
#   'favourites_count': 1358,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1093,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874542160011382784/1529607040',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
#Python: http://bit.ly/2Cc1G4h 

hashtags = '#abdsc #DataScience #BigData #DataScientists #Coding #BigData #DeepLearning  #MachineLearning, #Algorithms #AI #Valance #Sentiment #Analysis'
"New Tweet Analysis: %s (Thx @%s!!)" %
                              (target_account, requesting_user))

# %%
VADER_def = 'VADER Sentiment Analysis. VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media, and works well on texts from other domains.'
api.update_status(VADER_def )
# Out:
# {'created_at': 'Sun Oct 14 13:46:19 +0000 2018',
#  'id': 1051469251939393536,
#  'id_str': '1051469251939393536',
#  'text': 'VADER Sentiment Analysis. VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based senti… https://t.co/HH3xatG32Z',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/HH3xatG32Z',
#     'expanded_url': 'https://twitter.com/i/web/status/1051469251939393536',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="https://github.com/attila5287" rel="nofollow">Twitter_BigData_DU_Bootcamp_app</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 874542160011382784,
#   'id_str': '874542160011382784',
#   'name': 'Attila Türköz',
#   'screen_name': 'attila52__',
#   'location': 'Denver, CO',
#   'description': "#bogazici #sultans #BJK #denver #colorado #turkey #izmir #istanbul #ataturk #engineer #finance Bogazici ME’11-CTU,https://t.co/21K8KiJUm4'13-Denver Uni’18 #python #bigdata",
#   'url': 'https://t.co/BBmL0lVDO4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BBmL0lVDO4',
#       'expanded_url': 'http://www.bogazicisultans.com',
#       'display_url': 'bogazicisultans.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/21K8KiJUm4',
#       'expanded_url': 'http://MBA.Finance',
#       'display_url': 'MBA.Finance',
#       'indices': [114, 137]}]}},
#   'protected': False,
#   'followers_count': 54,
#   'friends_count': 613,
#   'listed_count': 1,
#   'created_at': 'Tue Jun 13 08:21:13 +0000 2017',
#   'favourites_count': 1358,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1092,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874542160011382784/1529607040',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
objectives = '\t[1] Pull last 100 tweets from each outlet. \n  \t[2]Perform a sentiment analysis with the compound,\n \t[3]positive, neutral, and negative scoring for each tweet.'
objectives2 = '\t[4] Pull into a DataFrame the tweets source account, its text, its date, and its compound, positive, neutral, and negative sentiment scores.'
objectives3 = ' \t[5] Export the data in the DataFrame into a CSV file. \n\t [6] Save PNG images for each plot then tweet out'

# %%
api.update_status(objectives3)
api.update_status(objectives2)
api.update_status(objectives)
# Out:
# {'created_at': 'Sun Oct 14 13:50:57 +0000 2018',
#  'id': 1051470417414811648,
#  'id_str': '1051470417414811648',
#  'text': '[1] Pull last 100 tweets from each outlet. \n  [2]Perform a sentiment analysis with the compound,\n [3]positive, neut… https://t.co/8prFqBrw0p',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/8prFqBrw0p',
#     'expanded_url': 'https://twitter.com/i/web/status/1051470417414811648',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="https://github.com/attila5287" rel="nofollow">Twitter_BigData_DU_Bootcamp_app</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 874542160011382784,
#   'id_str': '874542160011382784',
#   'name': 'Attila Türköz',
#   'screen_name': 'attila52__',
#   'location': 'Denver, CO',
#   'description': "#bogazici #sultans #BJK #denver #colorado #turkey #izmir #istanbul #ataturk #engineer #finance Bogazici ME’11-CTU,https://t.co/21K8KiJUm4'13-Denver Uni’18 #python #bigdata",
#   'url': 'https://t.co/BBmL0lVDO4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BBmL0lVDO4',
#       'expanded_url': 'http://www.bogazicisultans.com',
#       'display_url': 'bogazicisultans.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/21K8KiJUm4',
#       'expanded_url': 'http://MBA.Finance',
#       'display_url': 'MBA.Finance',
#       'indices': [114, 137]}]}},
#   'protected': False,
#   'followers_count': 54,
#   'friends_count': 613,
#   'listed_count': 1,
#   'created_at': 'Tue Jun 13 08:21:13 +0000 2017',
#   'favourites_count': 1358,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1095,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874542160011382784/1529607040',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
proj1 = 'BigData Project: create a Python script to perform a sentiment analysis of the Twitter activity of various news outlets, and to present your findings visually.'
proj2 = 'Output should provide a visualized summary of the sentiments expressed in Tweets sent out by the following news organizations: BBC, CBS, CNN, Fox, and New York times.'
api.update_status(proj2)
api.update_status(proj1)
# Out:
# {'created_at': 'Sun Oct 14 13:54:22 +0000 2018',
#  'id': 1051471275674259457,
#  'id_str': '1051471275674259457',
#  'text': 'BigData Project: create a Python script to perform a sentiment analysis of the Twitter activity of various news out… https://t.co/eOwfvUYRBF',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/eOwfvUYRBF',
#     'expanded_url': 'https://twitter.com/i/web/status/1051471275674259457',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="https://github.com/attila5287" rel="nofollow">Twitter_BigData_DU_Bootcamp_app</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 874542160011382784,
#   'id_str': '874542160011382784',
#   'name': 'Attila Türköz',
#   'screen_name': 'attila52__',
#   'location': 'Denver, CO',
#   'description': "#bogazici #sultans #BJK #denver #colorado #turkey #izmir #istanbul #ataturk #engineer #finance Bogazici ME’11-CTU,https://t.co/21K8KiJUm4'13-Denver Uni’18 #python #bigdata",
#   'url': 'https://t.co/BBmL0lVDO4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BBmL0lVDO4',
#       'expanded_url': 'http://www.bogazicisultans.com',
#       'display_url': 'bogazicisultans.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/21K8KiJUm4',
#       'expanded_url': 'http://MBA.Finance',
#       'display_url': 'MBA.Finance',
#       'indices': [114, 137]}]}},
#   'protected': False,
#   'followers_count': 54,
#   'friends_count': 613,
#   'listed_count': 1,
#   'created_at': 'Tue Jun 13 08:21:13 +0000 2017',
#   'favourites_count': 1358,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1097,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874542160011382784/1529607040',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
github = 'GitHub link for BigData VADER analysis AI project:\nhttps://github.com/attila5287/DU_BigData_hw7_twitter_api_python_pandas.git'
api.update_status(github)
# Out:
# {'created_at': 'Sun Oct 14 13:57:15 +0000 2018',
#  'id': 1051472003591536640,
#  'id_str': '1051472003591536640',
#  'text': 'GitHub link for BigData VADER analysis AI project:\nhttps://t.co/h2SvNwKfyo',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/h2SvNwKfyo',
#     'expanded_url': 'https://github.com/attila5287/DU_BigData_hw7_twitter_api_python_pandas.git',
#     'display_url': 'github.com/attila5287/DU_…',
#     'indices': [51, 74]}]},
#  'source': '<a href="https://github.com/attila5287" rel="nofollow">Twitter_BigData_DU_Bootcamp_app</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 874542160011382784,
#   'id_str': '874542160011382784',
#   'name': 'Attila Türköz',
#   'screen_name': 'attila52__',
#   'location': 'Denver, CO',
#   'description': "#bogazici #sultans #BJK #denver #colorado #turkey #izmir #istanbul #ataturk #engineer #finance Bogazici ME’11-CTU,https://t.co/21K8KiJUm4'13-Denver Uni’18 #python #bigdata",
#   'url': 'https://t.co/BBmL0lVDO4',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BBmL0lVDO4',
#       'expanded_url': 'http://www.bogazicisultans.com',
#       'display_url': 'bogazicisultans.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/21K8KiJUm4',
#       'expanded_url': 'http://MBA.Finance',
#       'display_url': 'MBA.Finance',
#       'indices': [114, 137]}]}},
#   'protected': False,
#   'followers_count': 54,
#   'friends_count': 613,
#   'listed_count': 1,
#   'created_at': 'Tue Jun 13 08:21:13 +0000 2017',
#   'favourites_count': 1358,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1098,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874544001025585152/kWnvx74m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874542160011382784/1529607040',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}
